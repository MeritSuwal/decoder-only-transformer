# %%
# !pip uninstall -y torch torchvision torchaudio
# !pip install torch==2.5.1 torchvision==0.20.1 torchaudio==2.5.1 --index-url https://download.pytorch.org/whl/cu121

# %%
import torch
import torch.nn as nn
from sklearn.model_selection import train_test_split
from torch.nn import functional as F

# %%
print("PyTorch:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("PyTorch CUDA:", torch.version.cuda)

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
    print("GPU capability:", torch.cuda.get_device_capability(0))
# Out:
# PyTorch: 2.5.1+cu121
# CUDA available: True
# PyTorch CUDA: 12.1
# GPU: Tesla P100-PCIE-16GB
# GPU capability: (6, 0)

# %%
batch_size = 64 #indep sequence processing in parallel
block_size = 256 #maximum context length for prediction
max_iters = 5000
eval_interval = 500
lr = 3e-4
device ='cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_emb_dim = 384
n_head = 6
n_layer = 6
dropout = 0.2

# %%
print(device)
# Out:
# cuda

# %%
# !python --version
# Out:
# Python 3.12.13

# %%
torch.manual_seed(3407)

# %%
with open('/kaggle/input/datasets/ikigaii/shakespear/input.txt', 'r', encoding='utf-8') as f:
    text = f.read()

print("Length (char):", len(text))
print(text[:500])
# Out:
# Length (char): 1115394
# First Citizen:
# Before we proceed any further, hear me speak.
#
# All:
# Speak, speak.
#
# First Citizen:
# You are all resolved rather to die than to famish?
#
# All:
# Resolved. resolved.
#
# First Citizen:
# First, you know Caius Marcius is chief enemy to the people.
#
# All:
# We know't, we know't.
#
# First Citizen:
# Let us kill him, and we'll have corn at our own price.
# Is't a verdict?
#
# All:
# No more talking on't; let it be done: away, away!
#
# Second Citizen:
# One word, good citizens.
#
# First Citizen:
# We are accounted poor

# %%
chars = sorted(list(set(text)))
vocab_size = len(chars)

# %%
print(vocab_size)
# Out:
# 65

# %%
str_to_int = { ch:i for i, ch in enumerate(chars) }
int_to_str = { i:ch for i, ch in enumerate(chars) }

# %%
encode = lambda s: [str_to_int[c] for c in s] #take a str and output a list of int

# %%
decode = lambda l: ''.join([int_to_str[i] for i in l]) #vice versa

# %%
print(encode("Meoww"))
# Out:
# [25, 43, 53, 61, 61]

# %%
print(decode([25, 43, 53, 61, 61]))
# Out:
# Meoww

# %% [markdown]
# ENCODING ENTIRE TEXT DATASET and then store it into torch.Tensor

# %%
data = torch.tensor(encode(text), dtype =torch.long)
print(data.shape, data.dtype)
# Out:
# torch.Size([1115394]) torch.int64

# %%
print(data[:100])
# Out:
# tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 14, 43, 44,
#         53, 56, 43,  1, 61, 43,  1, 54, 56, 53, 41, 43, 43, 42,  1, 39, 52, 63,
#          1, 44, 59, 56, 58, 46, 43, 56,  6,  1, 46, 43, 39, 56,  1, 51, 43,  1,
#         57, 54, 43, 39, 49,  8,  0,  0, 13, 50, 50, 10,  0, 31, 54, 43, 39, 49,
#          6,  1, 57, 54, 43, 39, 49,  8,  0,  0, 18, 47, 56, 57, 58,  1, 15, 47,
#         58, 47, 64, 43, 52, 10,  0, 37, 53, 59])

# %%
# train, val = train_test_split(data, train_size=0.9, random_state=0)

n = int(0.9*len(data)) # first 90% will be train
train = data[:n]
val= data[n:]

# %%
print(train.shape)
print(val.shape)
# Out:
# torch.Size([1003854])
# torch.Size([111540])

# %%
# block_size = 8
# train[:block_size+1] # efficiency + for making TF see context from as little as 1 to block size

#tf will never see more than block_size input and op is truncated. context for any thing between 1 to blocksize can be inferenced

# %% [markdown]
# we will have mini batches of multiple chunks of text stacked up on a single tensor. FOR efficiency and parallelization. KEEP GPU BUSY.

# %%
def get_batch (split):
    data = train if split == 'train' else val
    ix = torch.randint( len(data) - block_size, (batch_size,))
    x = torch.stack(
        [data[i: i+block_size] for i in ix]
    )
    y = torch.stack(
            [data[i+1: i+block_size+1] for i in ix]
    )
    x, y = x.to(device), y.to(device)
    return x, y

# %%
@torch.no_grad() #dont call backward which is mroe efficet, no need to store intermediate var
def estimate_loss():
    output = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for i in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[i] = loss.item()
        output[split] = losses.mean()
    model.train()
    return output

# %% [markdown]
# SELF ATTENTION HEAD

# %%
class Head(nn.Module):

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_emb_dim, head_size, bias = False)
        self.query = nn.Linear(n_emb_dim, head_size, bias = False)
        self.value = nn.Linear(n_emb_dim, head_size, bias = False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size))) #lower trig matrix

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B, T, C = x.shape
        k = self.key(x)
        q = self.query(x)

        #compute attention scires along with normalisation with dimension

        weights = q @ k.transpose( -2, -1) * C ** -0.5  #(B, T, C)  (B, C, T) -> (B, T, T)
        weights = weights.masked_fill(self.tril[:T, :T] == 0, float('-inf')) #for decoder block to mask out unwanted context
        weights = F.softmax(weights, dim = -1) #B, T, T

        #WEIGHTERD AGGREGATION
        v = self.value(x)
        output = weights @ v
        return output

# %%
class MultiHeadAttention(nn.Module):

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList( 
            [Head(head_size) for _ in range(num_heads)]
        )
        self.proj = nn.Linear(n_emb_dim, n_emb_dim)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat(
            [h(x) for h in self.heads], dim = -1
        ) #concat over channel dim
        out = self.proj(out) #linear tf
        return out

# %%
class FeedForward(nn.Module):

    def __init__(self, n_emb_dim):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_emb_dim,4*n_emb_dim),
            nn.ReLU(),
            nn.Linear(4*n_emb_dim, n_emb_dim), #projection layer
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x) #per token level ie all the tokens do this independently (think on the data individually)

# %%
class Block(nn.Module):

    def __init__(self, n_emb_dim, n_head):
        super().__init__()
        head_size = n_emb_dim // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedForward(n_emb_dim)
        self.ln1 = nn.LayerNorm(n_emb_dim)
        self.ln2 = nn.LayerNorm(n_emb_dim) #32 size ; mean and var over 32 numbers

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

# %%
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        self.token_embedding_table = nn.Embedding(vocab_size, n_emb_dim)
        self.position_embedding_table = nn.Embedding(block_size, n_emb_dim)
        self.blocks = nn.Sequential(*
            [Block(n_emb_dim, n_head=n_head) for _ in range(n_layer)]
        )
        self.ln_f = nn.LayerNorm(n_emb_dim)
        self.lm_head = nn.Linear(n_emb_dim, vocab_size)

    def forward(self, idx, targets=None):

        B, T = idx.shape
        #idx and targets are both (B, T) tensor
        token_emb = self.token_embedding_table(idx)  #(B, T, C)
        pos_emb = self.position_embedding_table(torch.arange(T, device = device)) # T, C ; INT from 0 to T-1; ALL these int get embeedded
        x = token_emb + pos_emb  #B,T,C

        #apply multi head self attention (B, T, ,C)
        x = self.blocks(x)

        x = self.ln_f(x)

        logits = self.lm_head(x) #(B, T, vocab_size) 

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):

            #crop idx upto the last block size
            crop_idx = idx[:, -block_size:]
            
            # get the predictions
            logits, loss = self(crop_idx)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

# %%
model = BigramLanguageModel()
m = model.to(device)

# %%
optimizer = torch.optim.AdamW(m.parameters(), lr = lr) #3e-4 for most networks but for small this works or even higher

# %%
for iter in range(max_iters):

    #every once in a while eval the loss on train and val sets
    if iter %eval_interval == 0:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    #sample a batch of data
    xb, yb = get_batch('train')

    #eval the loss
    logits, loss = m(xb, yb)
    optimizer.zero_grad(set_to_none=True) #setting grads in previous step to zero
    loss.backward() #get grad for all the param
    optimizer.step() #use grad to update param
# Out:
# step 0: train loss 4.3190, val loss 4.3233
# step 500: train loss 1.9406, val loss 2.0402
# step 1000: train loss 1.5480, val loss 1.7391
# step 1500: train loss 1.3954, val loss 1.6138
# step 2000: train loss 1.3011, val loss 1.5599
# step 2500: train loss 1.2260, val loss 1.5523
# step 3000: train loss 1.1673, val loss 1.5544
# step 3500: train loss 1.1041, val loss 1.5675
# step 4000: train loss 1.0382, val loss 1.6060
# step 4500: train loss 0.9642, val loss 1.6514

# %%
context = torch.zeros((1, 1), dtype=torch.long, device = device)
print(decode(m.generate(context, max_new_tokens=1800)[0].tolist()))
# Out:
# Hath not been rough: sin, nor I'll not,--
#
# Nurse:
# How now! why! What's thou? has must I go?
#
# ROMEO:
# Not then?
#
# Nurse:
# I have; been, seeing; I will play be serve,
# The sleet massage o' the seat of sorrow.
#
# JULIET:
# Go, be the queen.
#
# JULIET:
# O more on, that hath numme in place my voice,
# Without yield unoverventure, our love,
# That mought the queking the palmost.
#
# Second Murdaret:
# How far thou istal find our cares to the sight!
#
# JULIET:
# O God's name, my lord, and I must obey?
#
# JULIET:
# Why, shall not be young distinctedous lie in
# That King Lewis one change of God's hand,
# Tis but thus which timeles with Clarence winhed
# Hath tlizans reconceigns.
#
# LEONTES:
# Who's my mother?
#
# LADY CALLE:
# No, brother; more tell me, thou art a doune.
#
# LAUDY Citizen:
# They consortants, keep King Richard no kill confied
# To Rive is hearts; sex Stanley, Duke of Gloucester!
#
# CORIOLANUS:
# I'll not be, that still night.
#
# CAOLUS:
# How canst thou wilt amazed?
#
# Second Servingman:
# You would he mistress his majesty are plett
# To say 'Carriola for the common?' made me;
# And must is I said. Go sal your honours, when
# Shall for you a pilot on you. But now, have
# More made mistakes me proverty, and fine from this
# vaniant, never come a sentenence, all nobles
# But for the spirits of his fiery tale: that's a
# matter may pressing it: it is.
#
# JOHEN OF GARGANE:
# And make your majesty and know by the sleepy.
# How now! what a might that did shrew stuggard?
#
# KING RICHARD II:
# Cannot, good canst: but if I be, my look ingrace
# Shall fly the be beggar we again images,
# To lose whose declines of a wise.
#
# JULIET:
# I think not I can call up;
# Sometimes offer all know
# Your victors die. Now have you but seemicious
# To whither and let you you are.
#
# Second Servant:
# Well, good Sirrah, Catesby, the Earl of Wills,
# That's the prince; there's no morning.
